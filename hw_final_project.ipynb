# %%
# import required libraries
library(tidyverse)
library(repr)
library(tidymodels)

# %%
dass_data <- read_csv("dass_data.csv")
colnames(dass_data)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   country = col_character(),
#   major = col_character()
# )
#
# See spec(...) for full column specifications.
#   [1] "Q1A"                   "Q1I"                   "Q1E"
#   [4] "Q2A"                   "Q2I"                   "Q2E"
#   [7] "Q3A"                   "Q3I"                   "Q3E"
#  [10] "Q4A"                   "Q4I"                   "Q4E"
#  [13] "Q5A"                   "Q5I"                   "Q5E"
#  [16] "Q6A"                   "Q6I"                   "Q6E"
#  [19] "Q7A"                   "Q7I"                   "Q7E"
#  [22] "Q8A"                   "Q8I"                   "Q8E"
#  [25] "Q9A"                   "Q9I"                   "Q9E"
#  [28] "Q10A"                  "Q10I"                  "Q10E"
#  [31] "Q11A"                  "Q11I"                  "Q11E"
#  [34] "Q12A"                  "Q12I"                  "Q12E"
#  [37] "Q13A"                  "Q13I"                  "Q13E"
#  [40] "Q14A"                  "Q14I"                  "Q14E"
#  [43] "Q15A"                  "Q15I"                  "Q15E"
#  [46] "Q16A"                  "Q16I"                  "Q16E"
#  [49] "Q17A"                  "Q17I"                  "Q17E"
#  [52] "Q18A"                  "Q18I"                  "Q18E"
#  [55] "Q19A"                  "Q19I"                  "Q19E"
#  [58] "Q20A"                  "Q20I"                  "Q20E"
#  [61] "Q21A"                  "Q21I"                  "Q21E"
#  [64] "Q22A"                  "Q22I"                  "Q22E"
#  [67] "Q23A"                  "Q23I"                  "Q23E"
#  [70] "Q24A"                  "Q24I"                  "Q24E"
#  [73] "Q25A"                  "Q25I"                  "Q25E"
#  [76] "Q26A"                  "Q26I"                  "Q26E"
#  [79] "Q27A"                  "Q27I"                  "Q27E"
#  [82] "Q28A"                  "Q28I"                  "Q28E"
#  [85] "Q29A"                  "Q29I"                  "Q29E"
#  [88] "Q30A"                  "Q30I"                  "Q30E"
#  [91] "Q31A"                  "Q31I"                  "Q31E"
#  [94] "Q32A"                  "Q32I"                  "Q32E"
#  [97] "Q33A"                  "Q33I"                  "Q33E"
# [100] "Q34A"                  "Q34I"                  "Q34E"
# [103] "Q35A"                  "Q35I"                  "Q35E"
# [106] "Q36A"                  "Q36I"                  "Q36E"
# [109] "Q37A"                  "Q37I"                  "Q37E"
# [112] "Q38A"                  "Q38I"                  "Q38E"
# [115] "Q39A"                  "Q39I"                  "Q39E"
# [118] "Q40A"                  "Q40I"                  "Q40E"
# [121] "Q41A"                  "Q41I"                  "Q41E"
# [124] "Q42A"                  "Q42I"                  "Q42E"
# [127] "country"               "source"                "introelapse"
# [130] "testelapse"            "surveyelapse"          "TIPI1"
# [133] "TIPI2"                 "TIPI3"                 "TIPI4"
# [136] "TIPI5"                 "TIPI6"                 "TIPI7"
# [139] "TIPI8"                 "TIPI9"                 "TIPI10"
# [142] "VCL1"                  "VCL2"                  "VCL3"
# [145] "VCL4"                  "VCL5"                  "VCL6"
# [148] "VCL7"                  "VCL8"                  "VCL9"
# [151] "VCL10"                 "VCL11"                 "VCL12"
# [154] "VCL13"                 "VCL14"                 "VCL15"
# [157] "VCL16"                 "education"             "urban"
# [160] "gender"                "engnat"                "age"
# [163] "screensize"            "uniquenetworklocation" "hand"
# [166] "religion"              "orientation"           "race"
# [169] "voted"                 "married"               "familysize"
# [172] "major"

# %%
# I am going to assume we are not going to work with the demographic for now
# the VLC# columns seems interesting but it will be dropped for now
#The response time, duration, and position of question will also be dropped
#This leaves on the Q#A, TIPI, and VCL# coluums
dass_selected <- dass_data %>%
    select(ends_with("A") | starts_with("TIPI"))
names(dass_selected)
# Out:
#  [1] "Q1A"    "Q2A"    "Q3A"    "Q4A"    "Q5A"    "Q6A"    "Q7A"    "Q8A"
#  [9] "Q9A"    "Q10A"   "Q11A"   "Q12A"   "Q13A"   "Q14A"   "Q15A"   "Q16A"
# [17] "Q17A"   "Q18A"   "Q19A"   "Q20A"   "Q21A"   "Q22A"   "Q23A"   "Q24A"
# [25] "Q25A"   "Q26A"   "Q27A"   "Q28A"   "Q29A"   "Q30A"   "Q31A"   "Q32A"
# [33] "Q33A"   "Q34A"   "Q35A"   "Q36A"   "Q37A"   "Q38A"   "Q39A"   "Q40A"
# [41] "Q41A"   "Q42A"   "TIPI1"  "TIPI2"  "TIPI3"  "TIPI4"  "TIPI5"  "TIPI6"
# [49] "TIPI7"  "TIPI8"  "TIPI9"  "TIPI10"

# %%
#split data and assign training data to dass_train

dass_split <- initial_split(dass_selected, prop = 0.75, strata = Q13A)  
dass_train <- training(dass_split)   
dass_test <- testing(dass_split)

head(dass_train)
head(dass_test)
# Out:
#   Q1A Q2A Q3A Q4A Q5A Q6A Q7A Q8A Q9A Q10A ⋯ TIPI1 TIPI2 TIPI3 TIPI4 TIPI5
# 1 4   4   2   4   4   4   4   4   2   1    ⋯ 1     5     7     7     7
# 2 2   3   2   1   3   3   4   2   3   3    ⋯ 1     1     7     4     6
# 3 1   1   1   1   3   2   2   1   1   1    ⋯ 7     6     4     5     3
# 4 3   2   4   1   4   4   3   4   4   4    ⋯ 1     7     5     7     5
# 5 3   1   2   1   3   3   1   3   1   1    ⋯ 5     3     6     6     3
# 6 3   3   2   2   4   3   1   3   4   3    ⋯ 6     5     6     6     6
#   TIPI6 TIPI7 TIPI8 TIPI9 TIPI10
# 1 7     7     5     1     1
# 2 4     6     1     6     1
# 3 2     6     3     5     2
# 4 7     1     2     1     7
# 5 4     4     7     5     7
# 6 2     5     3     3     3
#   Q1A Q2A Q3A Q4A Q5A Q6A Q7A Q8A Q9A Q10A ⋯ TIPI1 TIPI2 TIPI3 TIPI4 TIPI5
# 1 4   1   2   3   4   4   3   4   3   2    ⋯ 6     5     4     7     5
# 2 3   1   4   1   4   3   1   3   2   4    ⋯ 2     5     2     2     5
# 3 2   2   3   4   4   2   4   4   4   3    ⋯ 2     5     3     6     5
# 4 1   1   2   1   3   1   1   3   3   2    ⋯ 2     1     6     1     7
# 5 1   1   2   3   4   1   3   3   3   4    ⋯ 2     5     6     5     3
# 6 4   4   3   4   3   4   4   4   4   3    ⋯ 1     4     5     7     5
#   TIPI6 TIPI7 TIPI8 TIPI9 TIPI10
# 1 4     7     7     1     5
# 2 6     5     5     3     2
# 3 5     5     6     3     3
# 4 7     7     2     6     7
# 5 2     6     3     5     5
# 6 7     6     7     1     4

# %%
# lets try this as a knn regression problem
dass_recipe <- recipe(Q13A ~ ., data = dass_selected) %>%
    step_scale(all_predictors()) %>%
    step_center(all_predictors())

dass_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 3) %>%
    set_engine("kknn") %>%
    set_mode("regression")

dass_fit <- workflow() %>%
    add_recipe(dass_recipe) %>%
    add_model(dass_spec) %>%
    fit(data = dass_train)

dass_summary <- dass_fit %>%
          predict(dass_test) %>%
          bind_cols(dass_test) %>%
          metrics(truth = Q13A, estimate = .pred)

dass_summary
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   0.6964609
# 2 rsq     standard   0.5945151
# 3 mae     standard   0.4983571

# %%
# further tuning the k value for best performance
set.seed(1234)

dass_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) %>%
    set_engine("kknn") %>%
    set_mode("regression")

dass_workflow <- workflow() %>%
    add_recipe(dass_recipe) %>%
    add_model(dass_spec_tune)

dass_vfold <- vfold_cv(dass_train, v = 5, strata = Q13A)

gridvals <- tibble(neighbors = seq(from = 1, to = 100, by = 10))

dass_results <- dass_workflow %>% tune_grid(resamples = dass_vfold, grid = gridvals) %>%
                    collect_metrics()

dass_min <- dass_results %>%
   filter(.metric == "rmse") %>%
   arrange(mean, std_err) %>% 
   slice(1)
dass_min
# Out:
#   neighbors .metric .estimator mean      n std_err    .config
# 1 41        rmse    standard   0.6413403 5 0.00468002 Model05

# %%
# the wide range tune showed 41 to be the best, we can do a more detailed close range tune
# tuning the k value for best performance
set.seed(1234)

dass_spec_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) %>%
    set_engine("kknn") %>%
    set_mode("regression")

dass_workflow <- workflow() %>%
    add_recipe(dass_recipe) %>%
    add_model(dass_spec_tune)

dass_vfold <- vfold_cv(dass_train, v = 2, strata = Q13A)

gridvals <- tibble(neighbors = seq(from = 30, to = 50, by = 1)) # changed here

dass_results <- dass_workflow %>% tune_grid(resamples = dass_vfold, grid = gridvals) %>%
                    collect_metrsics()

dass_min <- dass_results %>%
   filter(.metric == "rmse") %>%
   arrange(mean, std_err) %>% 
   slice(1)
dass_min
# Out:
#   neighbors .metric .estimator mean      n std_err      .config
# 1 42        rmse    standard   0.6448181 2 7.457832e-05 Model13

# %%
# it shows that the even with the most optimized k value, the rmse is still not very ideal.
# Since we have two distinct groups of predictors, Q questions and TIPI personality tests, we should split them up and see if that improves the code

dass_TP <- dass_data %>%
    select(ends_with("A") | starts_with("TIPI"))
names(dass_selected)
